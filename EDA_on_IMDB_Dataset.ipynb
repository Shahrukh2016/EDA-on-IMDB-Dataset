# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahrukh2016/EDA-on-IMDB-Dataset/blob/main/EDA_on_IMDB_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## You have been hired by a rookie movie producer to help him decide what type of movies to produce and which actors to cast. You have to back your recommendations based on thorough analysis of the data he shared with you which has the list of 3000 movies and the corresponding details.
#
# ## As a data scientist, you have to first explore the data and check its sanity.
#
# ## Further, you have to answer the following questions:
# 1. ### <b> Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.</b>
# 2. ### <b>This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)? </b>
# 3. ### <b> Find out the unique genres of movies in this dataset.</b>
# 4. ### <b> Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI? </b>
# 5. ### <b> Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor. </b>
# 6. ### <b>Top 3 directors prefer which actors the most? </b>

# %%
import numpy as np
import pandas as pd

# %%
imdb_df= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/AlmaBetter/Modules/Module 1: (Python for Data Science)/Topic 14: Pandas Operations/Data Files/Copy of imdb_data.csv")

# %%
imdb_df.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
# ...

# %%
imdb_df.loc[0,"crew"]
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
crew_list= eval(imdb_df.loc[0,"crew"])

# %%
len(crew_list)
# Out:
# 72

# %%
imdb_df.columns.values
# Out:
# array(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'Keywords',
#        'cast', 'crew', 'revenue'], dtype=object)

# %%
columns_to_keep=["budget", "genres", "imdb_id","original_language", "original_title", "cast", "crew", "revenue"]
imdb_df= imdb_df[columns_to_keep]

# %%
imdb_df.head(1)
# Out:
#      budget                          genres    imdb_id original_language  \
# 0  14000000  [{'id': 35, 'name': 'Comedy'}]  tt2637294                en
#
#            original_title                                               cast  \
# 0  Hot Tub Time Machine 2  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             3000 non-null   int64
#  1   genres             2993 non-null   object
#  2   imdb_id            3000 non-null   object
#  3   original_language  3000 non-null   object
#  4   original_title     3000 non-null   object
#  5   cast               2987 non-null   object
#  6   crew               2984 non-null   object
#  7   revenue            3000 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 187.6+ KB

# %%
imdb_non_null_df= imdb_df.dropna()

# %%
imdb_non_null_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2978 entries, 0 to 2999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             2978 non-null   int64
#  1   genres             2978 non-null   object
#  2   imdb_id            2978 non-null   object
#  3   original_language  2978 non-null   object
#  4   original_title     2978 non-null   object
#  5   cast               2978 non-null   object
#  6   crew               2978 non-null   object
#  7   revenue            2978 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 209.4+ KB

# %%
 def convert_string_to_list(str):
  return eval(str)

# %%
imdb_df.loc[~imdb_df["genres"].isna(),"genres"]= imdb_df.loc[~imdb_df["genres"].isna(),"genres"].apply(convert_string_to_list)

# %%
imdb_df.loc[~imdb_df["cast"].isna(),"cast"]= imdb_df.loc[~imdb_df["cast"].isna(),"cast"].apply(convert_string_to_list)

# %%
imdb_df.loc[~imdb_df["crew"].isna(),"crew"]= imdb_df.loc[~imdb_df["crew"].isna(),"crew"].apply(convert_string_to_list)

# %%
imdb_df_new= imdb_df.copy()

# %%
imdb_df_new[imdb_df_new["genres"].isna()]
# Out:
#        budget genres    imdb_id original_language  \
# 470   2000000    NaN  tt0349159                en
# 1622   400000    NaN  tt0261755                en
# 1814  2700000    NaN  tt0110289                it
# 1819        0    NaN  tt0352622                ru
# 2423   500000    NaN  tt0984177                en
# 2686        0    NaN  tt0833448                ru
# 2900   200000    NaN  tt1766044                en
#
#                                        original_title  \
# 470   The Book of Mormon Movie, Volume 1: The Journey
# 1622                                          Jackpot
# 1814                                     Курочка Ряба
# 1819                          Небо. Самолёт. Девушка.
# 2423                                        Amarkalam
# 2686                                             Лифт
# 2900                          Poslednyaya skazka Rity
#
#                                                    cast  \
# 470   [{'cast_id': 1, 'character': 'Sam', 'credit_id...
# ...

# %%
imdb_df_new.tail(1)
# Out:
#         budget                                             genres    imdb_id  \
# 2999  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...  tt1600195
#
#      original_language original_title  \
# 2999                en      Abduction
#
#                                                    cast  \
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew   revenue
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...  82087155

# %%
imdb_df_new.loc[imdb_df_new["budget"]<1000,"budget"]=imdb_df_new.loc[imdb_df_new["budget"]>=1000,"budget"].median()
imdb_df_new.loc[imdb_df_new["revenue"]<1000,"revenue"]=imdb_df_new.loc[imdb_df_new["revenue"]>=1000,"revenue"].median()

# %%
imdb_df_new.describe()
# Out:
#              budget       revenue
# count  3.000000e+03  3.000000e+03
# mean   2.708250e+07  6.705811e+07
# std    3.492773e+07  1.373917e+08
# min    2.500000e+03  1.404000e+03
# 25%    1.000000e+07  2.947600e+06
# 50%    1.645000e+07  1.748753e+07
# 75%    2.900000e+07  6.891920e+07
# max    3.800000e+08  1.519558e+09

# %%
imdb_df_new["profit"]= imdb_df_new["revenue"]-imdb_df_new["budget"]

# %%
imdb_df_new[["original_title", "profit"]][imdb_df_new["profit"]==imdb_df_new["profit"].max()]
# Out:
#      original_title      profit
# 1761      Furious 7  1316249360

# %%
max_profit_df= imdb_df_new[imdb_df_new["profit"]==imdb_df_new["profit"].max()]

# %%
max_profit_df
# Out:
#          budget                          genres    imdb_id original_language  \
# 1761  190000000  [{'id': 28, 'name': 'Action'}]  tt2820852                en
#
#      original_title                                               cast  \
# 1761      Furious 7  [{'cast_id': 17, 'character': 'Dominic Toretto...
#
#                                                    crew     revenue  \
# 1761  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
#
#           profit
# 1761  1316249360

# %%
crew_list= max_profit_df.iloc[0]["crew"]

# %%
crew_list[0]
# Out:
# {'credit_id': '52fe4cc8c3a36847f823e681',
#  'department': 'Production',
#  'gender': 2,
#  'id': 12835,
#  'job': 'Producer',
#  'name': 'Vin Diesel',
#  'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'}

# %%
Producer_list=[]
Director_list=[]
for elem in crew_list:
  if elem["job"]=="Producer":
    Producer_list.append(elem["name"])
  if elem["job"]=="Director":
        Director_list.append(elem["name"])

# %%
Producer_list, Director_list
# Out:
# (['Vin Diesel', 'Neal H. Moritz', 'Michael Fottrell', 'Brandon Birtell'],
#  ['James Wan'])

# %%
cast_list= max_profit_df.iloc[0]["cast"]

# %%
cast_list[0]
# Out:
# {'cast_id': 17,
#  'character': 'Dominic Toretto',
#  'credit_id': '5431dfd10e0a265915002c34',
#  'gender': 2,
#  'id': 12835,
#  'name': 'Vin Diesel',
#  'order': 0,
#  'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'}

# %%
actor_list=[]
for actor in cast_list:
  actor_list.append(actor["name"])

# %%
actor_list
# Out:
# ['Vin Diesel',
#  'Paul Walker',
#  'Dwayne Johnson',
#  'Michelle Rodriguez',
#  'Tyrese Gibson',
#  'Ludacris',
#  'Jordana Brewster',
#  'Djimon Hounsou',
#  'Tony Jaa',
#  'Ronda Rousey',
#  'Nathalie Emmanuel',
#  'Kurt Russell',
#  'Jason Statham',
#  'Sung Kang',
#  'Gal Gadot',
#  'Lucas Black',
#  'Elsa Pataky',
#  'Noel Gugliemi',
#  'John Brotherton',
#  'Luke Evans',
#  'Ali Fazal',
#  'Miller Kimsey',
#  'Charlie Kimsey',
#  'Eden Estrella',
#  'Gentry White',
#  'Iggy Azalea',
#  'Jon Lee Brody',
#  'Levy Tran',
#  'Anna Colwell',
#  'Viktor Hernandez',
#  'Steve Coulter',
#  'Robert Pralgo',
#  'Antwan Mills',
#  'J.J. Phillips',
#  'Jorge Ferragut',
#  'Sara Sohn',
#  'Benjamin Blankenship',
#  'D.J. Hapa',
#  'T-Pain',
#  'Brian Mahoney',
#  'Brittney Alger',
#  'Romeo Santos',
#  'Jocelin Donahue',
#  'Stephanie Langston',
#  'Jorge-Luis Pallo',
#  'Tego Calder√≥n',
#  'Nathalie Kelley',
#  'Shad Moss',
#  'Don Omar',
#  'Klement Tinaj',
#  'Caleb Walker',
# ...

# %%
imdb_df_new["roi"]= imdb_df_new["profit"]*100/imdb_df_new["budget"]

# %%
imdb_df_new.head(1)
# Out:
#      budget                          genres    imdb_id original_language  \
# 0  14000000  [{'id': 35, 'name': 'Comedy'}]  tt2637294                en
#
#            original_title                                               cast  \
# 0  Hot Tub Time Machine 2  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue   profit  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651 -1685349
#
#          roi
# 0 -12.038207

# %%
roi_languages_df= imdb_df_new.groupby(["original_language"])["roi"].mean().reset_index()
roi_languages_df
# Out:
#    original_language           roi
# 0                 ar    -91.807009
# 1                 bn    -96.739429
# 2                 cn     86.002479
# 3                 cs    -99.894267
# 4                 da     24.702661
# 5                 de    510.347257
# 6                 el   5198.013245
# 7                 en    929.987781
# 8                 es    103.433478
# 9                 fa      3.235168
# 10                fi    -30.319235
# 11                fr     51.900020
# 12                he    456.292450
# 13                hi    249.618424
# 14                hu    -95.535384
# 15                id    -41.617578
# 16                it     22.136747
# 17                ja    122.763087
# 18                ko  11277.949295
# 19                ml    370.833333
# 20                mr    193.333333
# 21                nb     18.847943
# 22                nl    -24.142008
# 23                no     24.155275
# 24                pl    395.816987
# 25                pt    -29.291459
# ...

# %%
max_roi_lan= roi_languages_df[roi_languages_df["roi"]==roi_languages_df["roi"].max()]
max_roi_lan
# Out:
#    original_language           roi
# 18                ko  11277.949295

# %% [markdown]
# Question:3

# %%
imdb_df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             3000 non-null   int64
#  1   genres             2993 non-null   object
#  2   imdb_id            3000 non-null   object
#  3   original_language  3000 non-null   object
#  4   original_title     3000 non-null   object
#  5   cast               2987 non-null   object
#  6   crew               2984 non-null   object
#  7   revenue            3000 non-null   int64
#  8   profit             3000 non-null   int64
#  9   roi                3000 non-null   float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 234.5+ KB

# %%
imdb_df_no_na_genres= imdb_df_new[~imdb_df_new["genres"].isna()]
imdb_df_no_na_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2993 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             2993 non-null   int64
#  1   genres             2993 non-null   object
#  2   imdb_id            2993 non-null   object
#  3   original_language  2993 non-null   object
#  4   original_title     2993 non-null   object
#  5   cast               2980 non-null   object
#  6   crew               2978 non-null   object
#  7   revenue            2993 non-null   int64
#  8   profit             2993 non-null   int64
#  9   roi                2993 non-null   float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 257.2+ KB

# %%
imdb_df_no_na_genres.head(1)
# Out:
#      budget                          genres    imdb_id original_language  \
# 0  14000000  [{'id': 35, 'name': 'Comedy'}]  tt2637294                en
#
#            original_title                                               cast  \
# 0  Hot Tub Time Machine 2  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue   profit  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651 -1685349
#
#          roi
# 0 -12.038207

# %%
imdb_df_no_na_genres.loc[0,"genres"]
# Out:
# [{'id': 35, 'name': 'Comedy'},
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy',
#  'Comedy']

# %%
imdb_df_no_na_genres.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x7f4c19164050>

# %%
genre_list=[]
for index,row in imdb_df_no_na_genres.iterrows():
  print(index,row)
  genre_list= imdb_df_no_na_genres.loc[index,"genres"]
  print(genre_list)
  for elem in genre_list:
    print(elem)
    genre_list.append(elem['name'])

# %%
imdb_df_no_na_crew=imdb_df_new[~imdb_df_new["crew"].isna()]

# %%
imdb_df_no_na_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2984 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             2984 non-null   int64
#  1   genres             2978 non-null   object
#  2   imdb_id            2984 non-null   object
#  3   original_language  2984 non-null   object
#  4   original_title     2984 non-null   object
#  5   cast               2984 non-null   object
#  6   crew               2984 non-null   object
#  7   revenue            2984 non-null   int64
#  8   profit             2984 non-null   int64
#  9   roi                2984 non-null   float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 256.4+ KB

# %%
imdb_df_no_na_crew.loc[1,"crew"]
# Out:
# [{'credit_id': '52fe43fe9251416c7502563d',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 1201,
#   'job': 'Director',
#   'name': 'Garry Marshall',
#   'profile_path': '/kx77E8p5rnEmKxIhFT0qWCEMEik.jpg'},
#  {'credit_id': '52fe43fe9251416c75025667',
#   'department': 'Camera',
#   'gender': 2,
#   'id': 1214,
#   'job': 'Director of Photography',
#   'name': 'Charles Minsky',
#   'profile_path': None},
#  {'credit_id': '52fe43fe9251416c75025661',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 4500,
#   'job': 'Original Music Composer',
#   'name': 'John Debney',
#   'profile_path': '/hTrlvZlDXQk49nfc2BM9sjKfJv.jpg'},
#  {'credit_id': '52fe43fe9251416c7502564f',
#   'department': 'Production',
#   'gender': 1,
#   'id': 8851,
#   'job': 'Producer',
#   'name': 'Whitney Houston',
#   'profile_path': '/69ouDnXnmklYPr4sMJXWKYz81AL.jpg'},
#  {'credit_id': '52fe43fe9251416c7502566d',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 12970,
#   'job': 'Editor',
# ...

# %%
def get_producres_and_directors(crew_list):
  try:
    producer_list=[]
    director_list=[]
    for elem in crew_list:
      if elem["job"]=="Producer":
        producer_list.append(elem["name"])

      if elem["job"]=="Director":
        director_list.append(elem["name"])
    return producer_list, director_list
  except:
    return [],[]

# %%
imdb_df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             3000 non-null   int64
#  1   genres             2993 non-null   object
#  2   imdb_id            3000 non-null   object
#  3   original_language  3000 non-null   object
#  4   original_title     3000 non-null   object
#  5   cast               2987 non-null   object
#  6   crew               2984 non-null   object
#  7   revenue            3000 non-null   int64
#  8   profit             3000 non-null   int64
#  9   roi                3000 non-null   float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 234.5+ KB

# %%
imdb_df_no_na_crew.loc[0,"crew"]
# Out:
# [{'credit_id': '59ac067c92514107af02c8c8',
#   'department': 'Directing',
#   'gender': 0,
#   'id': 1449071,
#   'job': 'First Assistant Director',
#   'name': 'Kelly Cantley',
#   'profile_path': None},
#  {'credit_id': '52fe4ee7c3a36847f82afad7',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 3227,
#   'job': 'Director',
#   'name': 'Steve Pink',
#   'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'},
#  {'credit_id': '5524ed25c3a3687ded000d88',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Writer',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed2d925141720c001128',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Characters',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed3d92514166c1004a5d',
#   'department': 'Production',
#   'gender': 2,
#   'id': 57822,
#   'job': 'Producer',
# ...

# %%
get_producres_and_directors(imdb_df_no_na_crew.loc[1,"crew"])
# Out:
# (['Whitney Houston', 'Mario Iscovich', 'Debra Martin Chase'],
#  ['Garry Marshall'])
